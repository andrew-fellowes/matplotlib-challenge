# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - In this study, the efficacy of nine compounds at controlling tumour growth was explored by measuring tumour volume over time in mice with squamous cell carcinoma.
# - Of the nine treatment regimens tested in this experiment, our lead compound Capomulin and one other (Ramicane) appeared to generate significantly more timepoints than the other seven compounds, which were not markedly different to placebo. This indicates a potential survival benefit for these compounds, which should be explored in further studies.
# - In addition, final tumour volumes were significantly smaller for Capomulin and Ramicane treated mice compared to tumours from mice treated with two compounds selected from the remainder of the compounds. This indicates that mice treated with Capomulin or Ramicane probably continued to experience an anti-tumour effect from these compounds through to day 45 when they were sacrificed. This is exemplified by the excellent treatment response observed for mouse r554 on Capomulin.
# - However we observed a significant correlation between average mouse weight and tumour volume which could be an uncontrolled and confounding factor in this study. This relationship should be explored further, by comparing the distribution of mouse weights for each treatment regime.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Plus we need numpy to create arrays
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data = pd.merge(study_results, mouse_metadata, how = "outer", on = "Mouse ID")
# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# write combined data to csv to do sanity checks in excel
# combined_data.to_csv("data/combined_data.csv")

# %%
# Checking the number of mice.
combined_data["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupes = combined_data[combined_data.duplicated(subset = ["Mouse ID", "Timepoint"], keep = False)]
dupes
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_g989 = combined_data.loc[combined_data["Mouse ID"] == "g989",:]
mouse_g989
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_data = combined_data.drop(combined_data.index[860:873])

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_data["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

tum_vol_by_drug = cleaned_data[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen")
avg_tum_vol = tum_vol_by_drug["Tumor Volume (mm3)"].mean()
med_tum_vol = tum_vol_by_drug["Tumor Volume (mm3)"].median()
var_tum_vol = tum_vol_by_drug["Tumor Volume (mm3)"].var()
std_tum_vol = tum_vol_by_drug["Tumor Volume (mm3)"].std()
sem_tum_vol = tum_vol_by_drug["Tumor Volume (mm3)"].sem()

# Assemble the resulting series into a single summary DataFrame.
summary_tum_vol_by_drug = pd.DataFrame({"Mean":avg_tum_vol, "Median": med_tum_vol, "Variance":var_tum_vol, "Std Dev":std_tum_vol, "SEM":sem_tum_vol})
summary_tum_vol_by_drug
# Out:
#                    Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
summary_tum_vol_by_drug2 = cleaned_data[["Drug Regimen", "Tumor Volume (mm3)"]].groupby("Drug Regimen").agg(["mean", "median", "var", "std", "sem"])
summary_tum_vol_by_drug2
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

timepoints_per_drug = cleaned_data[["Drug Regimen","Timepoint"]].groupby("Drug Regimen").count().plot(kind = "bar", title = "Total Timepoints per Drug Regimen", legend = False, ylabel = "Number of Timepoints")
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
x_axis = cleaned_data["Drug Regimen"].unique()
timepoints = cleaned_data[["Drug Regimen","Timepoint"]].groupby("Drug Regimen").count()
plt.bar(x_axis, timepoints["Timepoint"])
plt.title("Total Timepoints per Drug Regimen")
plt.ylabel("Number of Timepoints")
plt.xticks(rotation="vertical")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
# Note: if you use '.count' of 'cleaned_data', you will get a distorted sex ratio due to multiple counting of individual mice (922 F to 958 M) therefore I used .nunique
sex = cleaned_data[["Mouse ID", "Sex"]].groupby("Sex").nunique().plot.pie(y="Mouse ID", autopct="%.1f%%", ylabel = "Sex", legend = False)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_ratio = cleaned_data[["Mouse ID", "Sex"]].groupby("Sex").nunique()
plt.pie(sex_ratio["Mouse ID"], labels = sex_ratio.index, autopct="%.1f%%")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
final_timepoints = cleaned_data.groupby("Mouse ID").max("Timepoint")
final_timepoints = final_timepoints.drop(final_timepoints.columns[[1, 2, 3, 4]], axis = 1)

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
cleaned_final_timepoints = pd.merge(final_timepoints, cleaned_data, on=("Mouse ID", "Timepoint"), how = "left")
cleaned_final_timepoints
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
final_tumour_vols = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatments:    

    # Locate the rows which contain mice on each drug and get the tumor volumes
    drug_tumour_vols = cleaned_final_timepoints.loc[(cleaned_final_timepoints["Drug Regimen"] == drug), "Tumor Volume (mm3)"]
    
    # add subset 
    final_tumour_vols.append(drug_tumour_vols)

    # Determine outliers using upper and lower bounds
    Q1 = np.quantile(drug_tumour_vols, 0.25)
    Q2 = np.quantile(drug_tumour_vols, 0.5)
    Q3 = np.quantile(drug_tumour_vols, 0.75)
    iqr = Q3-Q1
    lbound = Q1 - (1.5*iqr)
    ubound = Q3 + (1.5*iqr)

    outliers = []
    for x in drug_tumour_vols:
        if (x < lbound or x > ubound):
            outliers.append(x)
    if len(outliers)==0:
        outliers.append("None")

    print(f"{drug}'s potential outliers: {outliers[0]}")
# Out:
# Capomulin's potential outliers: None
# Ramicane's potential outliers: None
# Infubinol's potential outliers: 36.3213458
# Ceftamin's potential outliers: None

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
ax1.set_title("Final Tumour Volume Ranges (mm3) by Regimen")
ax1.set_ylabel("Final Tumour Volume (mm3)")
ax1.boxplot(final_tumour_vols, labels = treatments, flierprops= dict(markerfacecolor="red", markersize=10))
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse_data = cleaned_data.loc[cleaned_data["Mouse ID"] == "r554",:]
x_axis = mouse_data["Timepoint"]
y_axis = mouse_data["Tumor Volume (mm3)"]
plt.plot(x_axis, y_axis)
plt.title("Treatment Response for Mouse r554 (Capomulin)")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumour Volume (mm3)")
plt.xlim(0,45)
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_data = cleaned_data.loc[cleaned_data["Drug Regimen"]=="Capomulin",:]
avg_capomulin = capomulin_data.groupby(["Mouse ID"]).mean(numeric_only = True)
x_values = avg_capomulin["Weight (g)"]
y_values = avg_capomulin["Tumor Volume (mm3)"]
plt.scatter(x_axis, y_axis)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumour Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(x_values,y_values)
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84

# %%
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumour Volume (mm3)")
plt.show()
